# %% [markdown]
#  Step 1: Import Python Libraries

# %% [markdown]
#  Import all libraries which are required for our analysis, such as
#  Data Loading, Statistical analysis, Visualizations, Data Trans
# formations, Merge and Joins, etc.

# %% [markdown]
#  Pandas and Numpy have been used for Data Manipulation and
#  numerical Calculations
#   Matplotlib and Seaborn have been used for Data visualizations

# %%
import pandas as pd
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# Step 2: Reading Dataset

# %% [markdown]
#  Most of the data are available in a tabular format of CSV files.
#  It is trendy and easy to access. Using the read_csv() function,
#  data can be converted to a pandas DataFrame.

# %%
Data=pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
Data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
Data.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
#  info() helps to understand the data type and information about
#  data, including the number of records in each column, data
#  having null or not null, Data type, the memory usage of the
#  dataset

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# Analyzing the Data

# %% [markdown]
#  Before we make any inferences, we listen to our data by examining all variables in the data.
#  The main goal of data understanding is to gain general insights about the data, which covers the
#  number of rows and columns, values in the data, datatypes, and Missing values in the dataset.
#  shape– shape will display the number of observations(rows) and features(columns) in the dataset
#  There are 2500 observations and 10 variables in our dataset
#  head() will display the top 5 observations of the dataset

# %% [markdown]
# Check for Duplication

# %% [markdown]
#  nunique() based on several unique values in each column and the data description, we can identify the continuous and
#  categorical columns in the data. Duplicated data can be handled or removed based on further analysis

# %%
Data.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %% [markdown]
#  Missing Values Calculation

# %% [markdown]
#  isnull() is widely been in all pre-processing steps to identify null values in the data
#  In our example, data.isnull().sum() is used to get the number of missing records in each column

# %% [markdown]
# The percentage of missing values for all the Columns Are 0 so
#  there is no need Of Data reduction

# %% [markdown]
# In this dataset customerID column  has no any predictive power  to predict the dependent variable.

# %%
# RemovecustomerID column from data
Data.drop("customerID",axis=1,inplace=True)
Data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# # The next step is to encode catogorical variables

# %% [markdown]
# Before encoding few things we need to keep in mind that some columns are nominal and some are ordinal so we need to encode it accordingly

# %% [markdown]
# For eg(gender,SeniorCitizen,partner,departments,PhoneService,PaperlessBilling,Churn) are nominal data and other catogirical variables are ordinal data

# %% [markdown]
# Apply Label encoding for nominal columns And One hot encoding for ordinal columns

# %% [markdown]
# There are some rows in OnlineSecurity,OnlineBackup,DeviceProtection,TechSupport,StreamingTV,StreamingMovies that contains NO Internrt as row so it will be better to convert it as no

# %%
columns_to_convert = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 
                      'TechSupport', 'StreamingTV', 'StreamingMovies']

# %%
for column in columns_to_convert:
    Data[column] = Data[column].replace('No internet service', 'No')

# %%
nominal_columns=['gender','SeniorCitizen','Partner','Dependents','PhoneService','PaperlessBilling','Churn','OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 
                      'TechSupport', 'StreamingTV', 'StreamingMovies']

# %%
from sklearn.preprocessing import LabelEncoder
label_mapping = {
    'gender': {'Female': 0, 'Male': 1},
    'Partner': {'No': 0, 'Yes': 1},
    'Dependents': {'No': 0, 'Yes': 1},
    'PhoneService': {'No': 0, 'Yes': 1},
    'PaperlessBilling': {'No': 0, 'Yes': 1},
    'Churn': {'No': 0, 'Yes': 1},
    'OnlineSecurity':{'No': 0, 'Yes': 1},
    'OnlineBackup':{'No': 0, 'Yes': 1},
    'DeviceProtection':{'No': 0, 'Yes': 1},
    'TechSupport':{'No': 0, 'Yes': 1},
    'StreamingTV':{'No': 0, 'Yes': 1},
    'StreamingMovies':{'No': 0, 'Yes': 1}
    
}

label_mapping = {}
for column in nominal_columns:
    label_mapping[column] = LabelEncoder()
    Data[column] = label_mapping[column].fit_transform(Data[column])

# %%
Data
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %% [markdown]
# Next we will convert Ordinal Catogorical Variable using One hot encoding

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int32
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int32
#  3   Dependents        7043 non-null   int32
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int32
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   int32
#  9   OnlineBackup      7043 non-null   int32
#  10  DeviceProtection  7043 non-null   int32
#  11  TechSupport       7043 non-null   int32
#  12  StreamingTV       7043 non-null   int32
#  13  StreamingMovies   7043 non-null   int32
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   int32
# ...

# %%
column_stats = Data['Contract'].describe()

# %%
column_stats
# Out:
# count               7043
# unique                 3
# top       Month-to-month
# freq                3875
# Name: Contract, dtype: object

# %%
unique_gender_values = Data['Contract'].unique()
print(unique_gender_values)
# Out:
# ['Month-to-month' 'One year' 'Two year']

# %%
unique_gender_values = Data['PaymentMethod'].unique()
print(unique_gender_values)
# Out:
# ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']

# %%
unique_gender_values = Data['InternetService'].unique()
print(unique_gender_values)
# Out:
# ['DSL' 'Fiber optic' 'No']

# %%
Data.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# In preprocessing step I fist analyse the data and remove the columns that serves no purpose in further analysis
# After that I encode the catogorical variable using label encoding ,In the next step i try to find out all the null values in each column
# ,it appears that Total charges column have some null valus so i remove null values with the median of the column

# %% [markdown]
# # After Data Preprocessing the next Step is Exploratory Data Analysis (EDA):

# %% [markdown]
#  Before we do EDA, lets separate Numerical and categorical variables for easy analysis

# %%
 cat_cols=Data.select_dtypes(include=['object']).columns
 num_cols = Data.select_dtypes(include=np.number).columns.tolist()
 print("Categorical Variables:")
 print(cat_cols)
 print("Numerical Variables:")
 print(num_cols)
# Out:
# Categorical Variables:
# Index(['MultipleLines', 'InternetService', 'Contract', 'PaymentMethod',
#        'TotalCharges'],
#       dtype='object')
# Numerical Variables:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'MonthlyCharges', 'Churn']

# %% [markdown]
# As i see i have total chargeas as object type so first convert it to float type

# %% [markdown]
# Lets first check for uniqiue value in Charges column

# %%
unique_gender_values = Data['TotalCharges'].unique()
print(unique_gender_values)
# Out:
# ['29.85' '1889.5' '108.15' ... '346.45' '306.6' '6844.5']

# %% [markdown]
# The column does not contain Any String so we can easily convert it into numerical column

# %%
Data['TotalCharges'] = pd.to_numeric(Data['TotalCharges'], errors='coerce')
num_cols = Data.select_dtypes(include=np.number).columns.tolist()
print(num_cols)
# Out:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
# Convert 'TotalCharges' to numeric, handle errors (coerce)
Data['TotalCharges'] = pd.to_numeric(Data['TotalCharges'], errors='coerce')

# Step 1: Calculate mean of 'TotalCharges' excluding NaN values
mean_total_charges = Data['TotalCharges'].mean()
print(f"Mean of TotalCharges: {mean_total_charges}")

# Step 2: Fill NaN values in 'TotalCharges' with the calculated mean
Data['TotalCharges'].fillna(mean_total_charges, inplace=True)

# Print unique values in 'TotalCharges' to verify
unique_total_charges = Data['TotalCharges'].unique()
print(unique_total_charges)
# Out:
# Mean of TotalCharges: 2283.3004408418656
# [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]

# %% [markdown]
# # UnivariatAnalysis

# %% [markdown]
# Univariate analysis can be done for both Categorical and Numerical variables.
#
# Categorical variables can be visualized using a Count plot, Bar Chart, Pie Plot, etc.
#
# Numerical Variables can be visualized using Histogram, Box Plot, Density Plot, etc.

# %%
# First lets  Do Univarite Analysis on Categorical Data

# %%
# Univariate Analysis on MultipleLines column
MultipleLines_type_count=Data['MultipleLines'].value_counts()
MultipleLines_type_percentage=Data['MultipleLines'].value_counts(normalize=True) * 100

# %%
#Bar chart 
plt.figure(figsize=(8, 6))
MultipleLines_type_count.plot(kind='bar')
plt.title("Distribution of MultipleLines")
plt.xlabel("MultipleLines_Count")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Percentage Distribution of MultipleLines Count
print("MultipleLines Type Count")
print(MultipleLines_type_count)
# Out:
# MultipleLines Type Count
# MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(MultipleLines_type_count, labels=MultipleLines_type_count.index,autopct='%1.1f%%', startangle=140)
plt.title("MultipleLines type Distribution")
 # Display the pie chart
plt.show()

# %% [markdown]
# As we can see moost of the users uses single line type Distribution and some users Does not use any kind of phone services

# %%
# Univariate Analysis on MultipleLines column
InternetService_type_count=Data['InternetService'].value_counts()
InternetService_type_percentage=Data['InternetService'].value_counts(normalize=True) * 100

# %%
#Bar chart 
plt.figure(figsize=(8, 6))
InternetService_type_count.plot(kind='bar')
plt.title("Distribution of Internet Service")
plt.xlabel("Internet Service_Count")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# As we see fibre optics has highest number of customers for using the internet Services

# %%
# Percentage Distribution of Internet Service Providers  Count
print("Internet Service provider Type Count")
print(InternetService_type_count)
# Out:
# Internet Service provider Type Count
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(InternetService_type_count, labels=InternetService_type_count.index,autopct='%1.1f%%', startangle=140)
plt.title("nternet Service provider Type Count")
 # Display the pie chart
plt.show()

# %%
# Univariate analysis on contract with customer Column
Contract_type_count=Data['Contract'].value_counts()
Contract_type_percentage=Data['Contract'].value_counts(normalize=True) * 100

# %%
#Bar chart 
plt.figure(figsize=(8, 6))
Contract_type_count.plot(kind='bar')
plt.title("Distribution of Contract with Customers ")
plt.xlabel("Contract Service Count")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(Contract_type_count, labels=Contract_type_count.index,autopct='%1.1f%%', startangle=140)
plt.title("Contract_type_count")
 # Display the pie chart
plt.show()

# %% [markdown]
# As we can see from this graph most of the customers are in the month to month contract. While there are equal number of customers in the 1 year and 2 year contracts.

# %%
# Univariate analysis on Payment Method 
PaymentMethod_type_count=Data['PaymentMethod'].value_counts()
PaymentMethod_type_percentage=Data['PaymentMethod'].value_counts(normalize=True) * 100

# %%
#Bar chart 
plt.figure(figsize=(8, 6))
PaymentMethod_type_count.plot(kind='bar')
plt.title("Distribution of PaymentMethod")
plt.xlabel("PaymentMethod Count")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# Univariate Analysis on numerical Data
#Calculate summary statistics for each numerical column:

# %%
for column in num_cols:
    print(column, ':')
    print(Data[column].describe())
# Out:
# gender :
# count    7043.000000
# mean        0.504756
# std         0.500013
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: gender, dtype: float64
# SeniorCitizen :
# count    7043.000000
# mean        0.162147
# std         0.368612
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: SeniorCitizen, dtype: float64
# Partner :
# count    7043.000000
# mean        0.483033
# std         0.499748
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Partner, dtype: float64
# Dependents :
# count    7043.000000
# mean        0.299588
# std         0.458110
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000
# Name: Dependents, dtype: float64
# tenure :
# count    7043.000000
# mean       32.371149
# ...

# %%
# Gender Distribution

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=Data, x='gender', palette='viridis')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Female', 'Male'])

# Calculate and annotate percentages
total = len(Data)
for p in plt.gca().patches:
    percentage = f'{100 * p.get_height() / total:.1f}%'
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 3
    plt.gca().annotate(percentage, (x, y), size=12)

plt.show()

# %%
# Percentage of Senior Citizen
plt.figure(figsize=(8, 6))
sns.countplot(data=Data, x='SeniorCitizen', palette='viridis')
plt.title('Senior Citizen Distribution')
plt.xlabel('Senior Citizen')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Not Senior', 'Senior'])

# Calculate and annotate percentages
total = len(Data)
for p in plt.gca().patches:
    percentage = f'{100 * p.get_height() / total:.1f}%'
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height() + 3
    plt.gca().annotate(percentage, (x, y), size=12)

plt.show()

# %%
# Lets do feature Engineering and Calculate the percentage of senior citizen male and female

# %%
# Assuming 'Data' is your DataFrame
total_count = len(Data)
gender_senior_counts = Data.groupby(['gender', 'SeniorCitizen']).size().reset_index(name='counts')
gender_senior_counts['percentage'] = gender_senior_counts['counts'] / total_count * 100

print(gender_senior_counts)
# Out:
#    gender  SeniorCitizen  counts  percentage
# 0       0              0    2920   41.459605
# 1       0              1     568    8.064745
# 2       1              0    2981   42.325713
# 3       1              1     574    8.149936

# %%
# Create DataFrame
df = pd.DataFrame(Data)

# Calculate percentage of male and female senior citizens
total_count = len(df)
gender_senior_counts = df.groupby(['gender', 'SeniorCitizen']).size().reset_index(name='counts')
gender_senior_counts['percentage'] = gender_senior_counts['counts'] / total_count * 100

# Plot
plt.figure(figsize=(8, 6))
sns.barplot(x='gender', y='percentage', hue='SeniorCitizen', data=gender_senior_counts, palette='viridis')
plt.title('Percentage of Male and Female Senior Citizens')
plt.xlabel('Gender')
plt.ylabel('Percentage')

# Annotate the bars with percentage values
for p in plt.gca().patches:
    percentage = f'{p.get_height():.1f}%'
    x = p.get_x() + p.get_width() / 2 - 0.05
    y = p.get_y() + p.get_height()
    plt.xticks(ticks=[0, 1], labels=['Female', 'Male'])
    plt.gca().annotate(percentage, (x, y), size=12, ha='center')

plt.legend(title='Senior Citizen', labels=['Not Senior', 'Senior'])
plt.show()

# %%
# As we can see 8.1 percentage of  citizens in both gender are senior citizens

# %%
Data.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 0  No phone service             DSL               0             1
# 1                No             DSL               1             0
# 2                No             DSL               1             1
# 3  No phone service             DSL               1             0
# 4                No     Fiber optic               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                 0            0            0                0
# ...

# %%
# Create DataFrame
Data = pd.DataFrame(Data)

# Melt the DataFrame
df2 = pd.melt(Data, value_vars=['Dependents', 'Partner'])
df3 = df2.groupby(['variable', 'value']).size().unstack()
df3 = df3 * 100 / len(Data)

# Plotting
colors = ['#32CD32', '#FFFF00'] 
ax = df3.plot.bar(stacked=True, color=colors, figsize=(8, 6), rot=0, width=0.2)

# Format y-axis as percentages
ax.set_yticklabels(['{:,.0%}'.format(x / 100) for x in ax.get_yticks()])
ax.set_ylabel('% Customers', size=14)
ax.set_xlabel('')
ax.set_title('% Customers with Dependents and Partners', size=14)
ax.legend(loc='center', prop={'size': 14}, title='')

# Annotate the bars with percentage values
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    ax.annotate('{:.0f}%'.format(height), (p.get_x() + .25 * width, p.get_y() + .4 * height),
                color='white',
                weight='bold',
                size=14)

plt.show()
# Out:
# C:\Users\khurr\AppData\Local\Temp\ipykernel_34244\434609236.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(['{:,.0%}'.format(x / 100) for x in ax.get_yticks()])

# %% [markdown]
# Partner and dependent status - About 50% of the customers have a partner, while only 30% of the total customers have dependents

# %% [markdown]
# *What would be interesting is to look at the % of customers, who have partners, also have dependents. We will explore this next. **
#
# Interestingly, among the customers who have a partner, only about half of them also have a dependent, while other half do not have any independents. Additionally, as expected, among the customers who do not have any partner, a majority (80%) of them do not have any dependents .

# %%
colors = ['#32CD32', '#FFFF00'] 
partner_dependents = Data.groupby(['Partner', 'Dependents']).size().unstack()

ax = (partner_dependents.T * 100.0 / partner_dependents.T.sum()).T.plot(kind='bar',
                                                                        width=0.2,
                                                                        stacked=True,
                                                                        rot=0,
                                                                        figsize=(8, 6),
                                                                        color=colors)
ax.legend(loc='center', prop={'size': 14}, title='Dependents', fontsize=14)
ax.set_ylabel('% Customers', size=14)
ax.set_title('% Customers with/without dependents based on whether they have a partner', size=14)
ax.xaxis.label.set_size(14)

# Code to add the data labels on the stacked bar chart
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    ax.annotate('{:.0f}%'.format(height), (p.get_x() + .25 * width, p.get_y() + .4 * height),
                color='white',
                weight='bold',
                size=14)

plt.show()

# %% [markdown]
# I also looked at any differences between the % of customers with/without dependents and partners by gender. There is no difference in their distribution by gender. Additionally, there is no difference in senior citizen status by gender.

# %% [markdown]
# # Lets Do univariate analysis on tenure part and the contract  column
# 1. Tenure: After looking at the below histogram we can see that a lot of customers have been with the telecom company for just a month, while quite a many are there for about 72 months. This could be potentially because different customers have different contracts. Thus based on the contract they are into it could be more/less easier for the customers to stay/leave the telecom company.

# %%
ax = sns.distplot(Data['tenure'], hist=True, kde=False, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
ax.set_ylabel(' Frequency of Customers')
ax.set_xlabel('Tenure (months)')
ax.set_title('Distribution  of Customers by their tenure')
# Out:
# C:\Users\khurr\AppData\Local\Temp\ipykernel_34244\52347910.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(Data['tenure'], hist=True, kde=False,
# Text(0.5, 1.0, 'Distribution  of Customers by their tenure')

# %% [markdown]
#  Contracts: To understand the above graph, lets first look at the  frequency of customers by different contracts.

# %%
ax = Data['Contract'].value_counts().plot(kind = 'bar',rot = 0, width = 0.3)
ax.set_ylabel('Frequency  of Customers')
ax.set_title(' Distribution of Customers by Contract Type')
# Out:
# Text(0.5, 1.0, ' Distribution of Customers by Contract Type')

# %% [markdown]
# As we can see from this graph most of the customers are in the month to month contract. While there are equal number of customers in the 1 year and 2 year contracts.

# %% [markdown]
#  lets understand the tenure of customers based on their contract type.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(20, 6))

ax = sns.distplot(Data[Data['Contract'] == 'Month-to-month']['tenure'],
                  hist=True, kde=False,
                  bins=int(180/5), color='turquoise',
                  hist_kws={'edgecolor': 'black'},
                  kde_kws={'linewidth': 4},
                  ax=ax1)
ax.set_ylabel('# of Customers')
ax.set_xlabel('Tenure (months)')
ax.set_title('Month to Month Contract')

ax = sns.distplot(Data[Data['Contract'] == 'One year']['tenure'],
                  hist=True, kde=False,
                  bins=int(180/5), color='steelblue',
                  hist_kws={'edgecolor': 'black'},
                  kde_kws={'linewidth': 4},
                  ax=ax2)
ax.set_xlabel('Tenure (months)', size=14)
ax.set_title('One Year Contract', size=14)

ax = sns.distplot(Data[Data['Contract'] == 'Two year']['tenure'],
                  hist=True, kde=False,
                  bins=int(180/5), color='darkblue',
                  hist_kws={'edgecolor': 'black'},
                  kde_kws={'linewidth': 4},
                  ax=ax3)

ax.set_xlabel('Tenure (months)')
ax.set_title('Two Year Contract')
plt.show()
# Out:
# C:\Users\khurr\AppData\Local\Temp\ipykernel_34244\1904645031.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(Data[Data['Contract'] == 'Month-to-month']['tenure'],
# C:\Users\khurr\AppData\Local\Temp\ipykernel_34244\1904645031.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# As we can see  most of the monthly contracts last for 1-2 months, while the 2 year contracts tend to last for about 70 months. This shows that the customers taking a longer contract are more loyal to the company and tend to stay with it for a longer period of time.
#
# This is also what we saw in the earlier chart on correlation with the churn rate.

# %% [markdown]
# let's take a quick look at the relation between monthly and total charges

# %%
Data.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#       MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 0  No phone service             DSL               0             1
# 1                No             DSL               1             0
# 2                No             DSL               1             1
# 3  No phone service             DSL               1             0
# 4                No     Fiber optic               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                 0            0            0                0
# ...

# %% [markdown]
# Lets Understand the distribution of various services used by customers

# %%
Services =['PhoneService','MultipleLines','InternetService','OnlineSecurity',
           'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 12))

for i, item in enumerate(Services):
    if i < 3:
        ax = Data[item].replace({0: 'No', 1: 'Yes'}).value_counts().plot(kind='bar', ax=axes[i, 0], rot=0)
    elif i >= 3 and i < 6:
        ax = Data[item].replace({0: 'No', 1: 'Yes'}).value_counts().plot(kind='bar', ax=axes[i - 3, 1], rot=0)
    elif i < 9:
        ax = Data[item].replace({0: 'No', 1: 'Yes'}).value_counts().plot(kind='bar', ax=axes[i - 6, 2], rot=0)
    ax.set_title(item)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bivate Analysis

# %% [markdown]
# As we see Our Target variable in to predict the chutn variable
# lets  find relationship of different columns with Churn

# %% [markdown]
# Lets First ckeck the distribution of churn rate

# %%
churn_rate = Data['Churn'].value_counts(normalize=True) * 100

plt.figure(figsize=(6, 6))
ax = sns.barplot(x=churn_rate.index, y=churn_rate.values, palette='viridis')
plt.title('Churn Rate Distribution')
plt.xlabel('Churn')
plt.ylabel('Percentage')
plt.xticks(ticks=[0, 1], labels=['No Churn', 'Churn'])

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.2f}%', (x + width/2, y + height + 1), ha='center')

plt.show()

# %% [markdown]
# As we can See In our data, approx  74% of the customers do not churn. Clearly the data is skewed as we would expect a large majority of the customers to not churn. This is important to keep in mind for our modelling as skeweness could lead to a lot of false negatives. We will see in the modelling section on how to avoid skewness in the data.

# %% [markdown]
# Lets now explore the churn rate by tenure, seniority, contract type, monthly charges and total charges to see how it varies by these variables.

# %% [markdown]
# # Churn vs Tenure:

# %%
sns.boxplot(x = Data.Churn, y = Data.tenure)
# Out:
# <Axes: xlabel='Churn', ylabel='tenure'>

# %% [markdown]
#  As we can see form the below plot, the customers who do not churn, they tend to stay for a longer tenure with the telecom company.

# %% [markdown]
# # Churn by Contract Type

# %%
colors = ['#32CD32', '#0000FF'] 
contract_churn = Data.groupby(['Contract', 'Churn']).size().unstack()

# Calculate the percentage of churn for each contract type
contract_churn_percent = (contract_churn.div(contract_churn.sum(axis=1), axis=0) * 100).round(2)

# Plotting the stacked bar chart
ax = contract_churn_percent.plot(kind='bar', stacked=True, width=0.3, color=colors, figsize=(10, 6), rot=0)

# Adding labels and title
ax.set_ylabel('% Customers', size=14)
ax.set_title('Churn by Contract Type', size=14)
ax.legend(loc='best', title='Churn', prop={'size': 14})

# Adding data labels on the stacked bar chart
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.0f}%', (p.get_x() + width/2, p.get_y() + height/2),
                ha='center', va='center', color='white', weight='bold', size=14)

plt.show()

# %% [markdown]
#  Similar to what we saw in the correlation plot, the customers who have a month to month contract have a very high churn rate

# %% [markdown]
# # Churn by Seniority

# %%
colors = ['#32CD32', '#0000FF']
seniority_churn = Data.groupby(['SeniorCitizen', 'Churn']).size().unstack()

# Calculate the percentage of churn for each seniority level
seniority_churn_percent = (seniority_churn.div(seniority_churn.sum(axis=1), axis=0) * 100).round(2)

# Plotting the stacked bar chart
ax = seniority_churn_percent.plot(kind='bar', stacked=True, width=0.2, color=colors, figsize=(8, 6), rot=0)

# Adding labels and title
ax.set_ylabel('% Customers')
ax.set_title('Churn by Seniority Level', size=14)
ax.legend(loc='center', prop={'size': 14}, title='Churn')

# Adding data labels on the stacked bar chart
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.0f}%', (p.get_x() + width/2, p.get_y() + height/2),
                ha='center', va='center', color='white', weight='bold', size=14)

plt.show()

# %% [markdown]
# As wr see Senior Citizens have almost double the churn rate than younger population.

# %% [markdown]
# # Churn by Monthly Charges

# %%
ax = sns.kdeplot(Data.MonthlyCharges[(Data["Churn"] == 'No') ],
                color="Red", shade = True)
ax = sns.kdeplot(Data.MonthlyCharges[(Data["Churn"] == 'Yes') ],
                ax =ax, color="Blue", shade= True)
ax.legend(["Not Churn","Churn"],loc='upper right')
ax.set_ylabel('Density')
ax.set_xlabel('Monthly Charges')
ax.set_title('Distribution of monthly charges by churn')
# Out:
# C:\Users\khurr\AppData\Local\Temp\ipykernel_34244\2954408036.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(Data.MonthlyCharges[(Data["Churn"] == 'No') ],
# C:\Users\khurr\AppData\Local\Temp\ipykernel_34244\2954408036.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   ax = sns.kdeplot(Data.MonthlyCharges[(Data["Churn"] == 'Yes') ],
# Text(0.5, 1.0, 'Distribution of monthly charges by churn')

# %% [markdown]
#  As We Observe Higher % of customers churn when the monthly charges are high.

# %% [markdown]
# # Now we Have COMPLETED THE EDA PART AND GAINED THE INSIGHTS ITS TIME TO DEVELOP SOME PREDICTIVE MODELS AND COMPARE ITS ACCURACY

# %%
Data.TotalCharges = pd.to_numeric(Data.TotalCharges, errors='coerce')

# %%
Data['Churn'].replace(to_replace='Yes', value=1, inplace=True)
Data['Churn'].replace(to_replace='No',  value=0, inplace=True)

# %%
encoded_df = pd.get_dummies(Data,dtype=float)
encoded_df.dropna(inplace=True)

# %%
#Get Correlation of "Churn" with other variables:
plt.figure(figsize=(15,8))
encoded_df.corr()['Churn'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## Logistic Regression

# %%
# We will use the data frame where we had created dummy variables
y = encoded_df['Churn'].values
X = encoded_df.drop(columns = ['Churn'])

# Scaling all the variables to a range of 0 to 1
from sklearn.preprocessing import MinMaxScaler
features = X.columns.values
scaler = MinMaxScaler(feature_range = (0,1))
scaler.fit(X)
X = pd.DataFrame(scaler.transform(X))
X.columns = features

# %%
# Create Train & Test Data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
# Running logistic regression model
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
result = model.fit(X_train, y_train)
# Out:
# C:\Users\khurr\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn import metrics
prediction_test = model.predict(X_test)
# Print the prediction accuracy
print (metrics.accuracy_score(y_test, prediction_test))
# Out:
# 0.8075829383886256

# %% [markdown]
# Scaling the variables in logistic regression is a pivotal step that can significantly enhance model accuracy. By ensuring that all variables are within a standardized range of 0 to 1, the model becomes more robust and better equipped to handle diverse data inputs. In my experience, this transformation led to a noticeable improvement, elevating accuracy from 79.7% to 80.7%.
#
# Additionally, the scaling process offers a coherent alignment between variable importance as observed in Random Forest algorithms and the insights gleaned from exploratory data analysis (EDA). This synchronization underscores the effectiveness of scaling in logistic regression, as it enables the model to leverage the most influential features accurately, ultimately contributing to enhanced predictive performance

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
model = RandomForestClassifier(n_estimators=1000 , oob_score = True, n_jobs = -1,
                                  random_state =50,
                                  max_leaf_nodes = 30)
model.fit(X_train, y_train)

# Make predictions
prediction_test = model.predict(X_test)
print (metrics.accuracy_score(y_test, prediction_test))
# Out:
# 0.8159203980099502

# %% [markdown]
# The insights extracted from the random forest algorithm shed light on key predictors of churn: monthly contract, tenure, and total charges emerge as highly influential variables. These findings closely mirror the outcomes of logistic regression and are in perfect harmony with the expectations we derived from our exploratory data analysis (EDA). This consistency across different methodologies underscores the reliability and robustness of our predictive models, reinforcing our confidence in their ability to accurately forecast churn patterns.

# %% [markdown]
# ## Support Vector Machine

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99)

# %%
from sklearn.svm import SVC

model.svm = SVC(kernel='linear') 
model.svm.fit(X_train,y_train)
preds = model.svm.predict(X_test)
metrics.accuracy_score(y_test, preds)
# Out:
# 0.8187633262260128

# %% [markdown]
# In this journey of refining our churn prediction model, we've witnessed a significant enhancement in accuracy, particularly with the SVM algorithm, achieving an impressive 82% accuracy rate. However, accuracy alone doesn't provide a complete picture of model performance. Therefore, our next steps involve a thorough examination of metrics such as true positive and true negative rates, as well as calculating the Area Under the Curve (AUC) to gain a deeper understanding of our model's predictive power.
#
# By delving into these metrics, we aim to uncover insights that go beyond simple accuracy figures. This comprehensive analysis will allow us to make informed decisions about our model's strengths and areas for improvement, ultimately leading to more robust and reliable churn predictions. Stay tuned for updates as we continue to refine and optimize our predictive model for even better performance!
